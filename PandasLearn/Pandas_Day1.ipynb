# %%
import pandas as pd

# %%
df = pd.read_csv("emp.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     eno    ename  salary  deptno         doj
# 0    10    Amber    1000      10  2018-05-14
# 1     2     Amar    1000      10  2017-03-22
# 2     8    Sagar    1000      20  2020-11-30
# 3     4   Thomas    1000      10  2019-08-18
# 4     5     Jade    2000      10  2021-02-10
# 5     6    Smith    1000      10  2016-12-01
# 6     7   Robert    3000      20  2023-06-25
# 7     3     Nick    1000      30  2015-09-15
# 8     9    Naman    4000      30  2020-01-20
# 9     1    Vikas    1000      30  2017-10-03
# 10   11   Dennis   41000      30  2024-01-05
# 11   12    Karan    2200      20  2018-06-16
# 12   13   Simran    1500      10  2019-12-19
# 13   14     Amit    2000      30  2022-04-09
# 14   15     Neha    1700      20  2021-07-22
# 15   16    Rahul    1200      10  2016-03-28
# 16   17    Divya    3000      30  2015-11-11
# 17   18   Rakesh    1800      10  2020-09-04
# 18   19   Monica    2500      20  2023-08-07
# 19   20     John    2300      30  2018-10-29
# ...

# %%
# Select only eno from the dataframe
# SQL : select eno from emp
df['eno']
# Out:
# 0     10
# 1      2
# 2      8
# 3      4
# 4      5
# 5      6
# 6      7
# 7      3
# 8      9
# 9      1
# 10    11
# 11    12
# 12    13
# 13    14
# 14    15
# 15    16
# 16    17
# 17    18
# 18    19
# 19    20
# 20    21
# 21    22
# 22    23
# 23    24
# 24    25
# 25    26
# 26    27
# 27    28
# 28    29
# 29    30
# 30    31
# 31    32
# 32    33
# 33    34
# 34    35
# 35    36
# 36    37
# 37    38
# 38    39
# 39    40
# 40    41
# 41    42
# 42    43
# 43    44
# 44    45
# 45    46
# 46    47
# Name: eno, dtype: int64

# %%
# Fetch eno and salary from the dataframe
# SQL : select eno,salary from emp
df[['eno','salary']]
# Out:
#     eno  salary
# 0    10    1000
# 1     2    1000
# 2     8    1000
# 3     4    1000
# 4     5    2000
# 5     6    1000
# 6     7    3000
# 7     3    1000
# 8     9    4000
# 9     1    1000
# 10   11   41000
# 11   12    2200
# 12   13    1500
# 13   14    2000
# 14   15    1700
# 15   16    1200
# 16   17    3000
# 17   18    1800
# 18   19    2500
# 19   20    2300
# 20   21    2700
# 21   22    1000
# 22   23    1500
# 23   24    1800
# 24   25    2000
# 25   26    1600
# 26   27    1400
# 27   28    1300
# 28   29    1200
# 29   30    1100
# 30   31    1900
# 31   32    2100
# 32   33    2400
# 33   34    2000
# 34   35    3000
# 35   36    3200
# 36   37    2800
# 37   38    2700
# 38   39    2600
# 39   40    2500
# 40   41    2300
# 41   42    2200
# 42   43    2100
# 43   44    1900
# 44   45    1800
# 45   46    1700
# 46   47    1600

# %%
# Fetch eno and salary from the dataframe
# SQL : select eno,salary from emp
col_list = ['eno','salary']
df[col_list]

df[['eno','salary']]
# Out:
#     eno  salary
# 0    10    1000
# 1     2    1000
# 2     8    1000
# 3     4    1000
# 4     5    2000
# 5     6    1000
# 6     7    3000
# 7     3    1000
# 8     9    4000
# 9     1    1000
# 10   11   41000
# 11   12    2200
# 12   13    1500
# 13   14    2000
# 14   15    1700
# 15   16    1200
# 16   17    3000
# 17   18    1800
# 18   19    2500
# 19   20    2300
# 20   21    2700
# 21   22    1000
# 22   23    1500
# 23   24    1800
# 24   25    2000
# 25   26    1600
# 26   27    1400
# 27   28    1300
# 28   29    1200
# 29   30    1100
# 30   31    1900
# 31   32    2100
# 32   33    2400
# 33   34    2000
# 34   35    3000
# 35   36    3200
# 36   37    2800
# 37   38    2700
# 38   39    2600
# 39   40    2500
# 40   41    2300
# 41   42    2200
# 42   43    2100
# 43   44    1900
# 44   45    1800
# 45   46    1700
# 46   47    1600

# %%
df = pd.read_csv("emp.csv",usecols=["eno","salary","deptno"])

# %%
df
# Out:
#     eno  salary  deptno
# 0    10    1000      10
# 1     2    1000      10
# 2     8    1000      20
# 3     4    1000      10
# 4     5    2000      10
# 5     6    1000      10
# 6     7    3000      20
# 7     3    1000      30
# 8     9    4000      30
# 9     1    1000      30
# 10   11   41000      30
# 11   12    2200      20
# 12   13    1500      10
# 13   14    2000      30
# 14   15    1700      20
# 15   16    1200      10
# 16   17    3000      30
# 17   18    1800      10
# 18   19    2500      20
# 19   20    2300      30
# 20   21    2700      10
# 21   22    1000      20
# 22   23    1500      30
# 23   24    1800      10
# 24   25    2000      20
# 25   26    1600      10
# 26   27    1400      30
# 27   28    1300      10
# 28   29    1200      20
# 29   30    1100      10
# 30   31    1900      20
# 31   32    2100      10
# 32   33    2400      30
# 33   34    2000      20
# 34   35    3000      10
# 35   36    3200      20
# 36   37    2800      30
# ...

# %%
# Display first 10 rows
df.head()
# Out:
#    eno  salary  deptno
# 0   10    1000      10
# 1    2    1000      10
# 2    8    1000      20
# 3    4    1000      10
# 4    5    2000      10

# %%
# Display first 10 rows
df.head(10)
# Out:
#    eno  salary  deptno
# 0   10    1000      10
# 1    2    1000      10
# 2    8    1000      20
# 3    4    1000      10
# 4    5    2000      10
# 5    6    1000      10
# 6    7    3000      20
# 7    3    1000      30
# 8    9    4000      30
# 9    1    1000      30

# %%
# Get me last 15 rows from the df
df.tail(15)
# Out:
#     eno  salary  deptno
# 32   33    2400      30
# 33   34    2000      20
# 34   35    3000      10
# 35   36    3200      20
# 36   37    2800      30
# 37   38    2700      10
# 38   39    2600      20
# 39   40    2500      30
# 40   41    2300      20
# 41   42    2200      10
# 42   43    2100      30
# 43   44    1900      10
# 44   45    1800      20
# 45   46    1700      30
# 46   47    1600      20

# %%
# I need 19th row
df_19 = df.head(19)

# %%
df_19.tail(1)
# Out:
#     eno  salary  deptno
# 18   19    2500      20

# %%
df.head(19).tail(1)
# Out:
#     eno  salary  deptno
# 18   19    2500      20

# %%
# get the details about the dataframe ( similar to desc tablename)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   eno     47 non-null     int64
#  1   salary  47 non-null     int64
#  2   deptno  47 non-null     int64
# dtypes: int64(3)
# memory usage: 1.2 KB

# %%
# get all the columns from the dataframe
df.columns
# Out:
# Index(['eno', 'salary', 'deptno'], dtype='object')

# %%
# get the datatypes of each columns in the dataframe
df.dtypes
# Out:
# eno       int64
# salary    int64
# deptno    int64
# dtype: object

# %%
df = pd.read_csv("emp.csv",dtype={"salary":float},parse_dates=['doj'])

# %%
df.dtypes
# Out:
# eno                int64
# ename             object
# salary           float64
# deptno             int64
# doj       datetime64[ns]
# dtype: object

# %%
# Various functions on date column ( doj)
df['doj'].dt.year
df['doj'].dt.month
df['doj'].dt.day
df['doj'].dt.weekday
# Out:
# 0     0
# 1     2
# 2     0
# 3     6
# 4     2
# 5     3
# 6     6
# 7     1
# 8     0
# 9     1
# 10    4
# 11    5
# 12    3
# 13    5
# 14    3
# 15    0
# 16    2
# 17    4
# 18    0
# 19    0
# 20    2
# 21    4
# 22    1
# 23    5
# 24    4
# 25    5
# 26    6
# 27    4
# 28    5
# 29    6
# 30    3
# 31    4
# 32    3
# 33    0
# 34    4
# 35    0
# 36    5
# 37    5
# 38    5
# 39    6
# 40    4
# 41    5
# 42    1
# 43    2
# 44    4
# 45    2
# 46    5
# Name: doj, dtype: int32

# %%
# Read the row number 11 to 15 and create a result csv file to store this data
# select ename,salary from emp where row_num in (10,16)
df_ans = df[['ename','salary']].iloc[10:16]
df_ans.to_csv("emp_ans.csv",index=False)

# %%
# Read the row number 11 to 15 and create a result csv file to store this data
df_ans = df[['ename','salary']].iloc[10:16]
df_ans.to_csv("emp_ans.csv",index=False)

# %%
# Can we read only selected rown numbers from the file ( row 10 to 20)
df = pd.read_csv("emp.csv",skiprows=10,nrows=10)

# %%
df
# Out:
#     1   Vikas   1000  30  2017-10-03
# 0  11  Dennis  41000  30  2024-01-05
# 1  12   Karan   2200  20  2018-06-16
# 2  13  Simran   1500  10  2019-12-19
# 3  14    Amit   2000  30  2022-04-09
# 4  15    Neha   1700  20  2021-07-22
# 5  16   Rahul   1200  10  2016-03-28
# 6  17   Divya   3000  30  2015-11-11
# 7  18  Rakesh   1800  10  2020-09-04
# 8  19  Monica   2500  20  2023-08-07
# 9  20    John   2300  30  2018-10-29

# %%
df = pd.read_csv("emp1.csv")

# %%
# Read the huge files in chunk
for chnk in pd.read_csv("emp1.csv",chunksize=5):
    print(chnk)
# Out:
#    eno   ename  salary  deptno         doj
# 0   10   Amber    1000      10  2018-05-14
# 1    2    Amar    1000      10  2017-03-22
# 2    8   Sagar    1000      20  2020-11-30
# 3    4  Thomas    1000      10  2019-08-18
# 4    5    Jade    2000      10  2021-02-10
#    eno   ename  salary  deptno         doj
# 5    6   Smith    1000      10  2016-12-01
# 6    7  Robert    3000      20  2023-06-25
# 7    3    Nick    1000      30  2015-09-15
# 8    9   Naman    4000      30  2020-01-20
# 9    1   Vikas    1000      30  2017-10-03
#     eno   ename  salary  deptno         doj
# 10   11  Dennis   41000      30  2024-01-05
# 11   12   Karan    2200      20  2018-06-16
# 12   13  Simran    1500      10  2019-12-19
# 13   14    Amit    2000      30  2022-04-09
# 14   15    Neha    1700      20  2021-07-22
#     eno   ename  salary  deptno         doj
# 15   16   Rahul    1200      10  2016-03-28
# 16   17   Divya    3000      30  2015-11-11
# 17   18  Rakesh    1800      10  2020-09-04
# ...

# %%
# low_memory = True by default
df = pd.read_csv("emp.csv",low_memory=False)

# %%
# Customer date forma
df = pd.read_csv("emp.csv")
#df['doj'] = pd.to_datetime(df['doj'].str.strip(), format="%d/%m/%Y")

# %%
df = pd.read_csv("emp.csv", parse_dates=['doj'])
df['doj'] = df['doj'].dt.strftime('%d-%m-%Y')

# %%
df
# Out:
#     eno    ename  salary  deptno       doj
# 0    10    Amber    1000      10  14-05-18
# 1     2     Amar    1000      10  22-03-17
# 2     8    Sagar    1000      20  30-11-20
# 3     4   Thomas    1000      10  18-08-19
# 4     5     Jade    2000      10  10-02-21
# 5     6    Smith    1000      10  01-12-16
# 6     7   Robert    3000      20  25-06-23
# 7     3     Nick    1000      30  15-09-15
# 8     9    Naman    4000      30  20-01-20
# 9     1    Vikas    1000      30  03-10-17
# 10   11   Dennis   41000      30  05-01-24
# 11   12    Karan    2200      20  16-06-18
# 12   13   Simran    1500      10  19-12-19
# 13   14     Amit    2000      30  09-04-22
# 14   15     Neha    1700      20  22-07-21
# 15   16    Rahul    1200      10  28-03-16
# 16   17    Divya    3000      30  11-11-15
# 17   18   Rakesh    1800      10  04-09-20
# 18   19   Monica    2500      20  07-08-23
# 19   20     John    2300      30  29-10-18
# 20   21    Sneha    2700      10  14-12-22
# ...
